# %%
import matplotlib.pyplot as plt #matplotlib.pyplot 을 plt로 불러왔다
# %matplotlib inline

plt.rc('font', family='Malgun Gothic')
print(plt.rcParams['font.family'])  ## Malgun Gothic 이라는 글꼴을 불러온다
# Out:
# ['Malgun Gothic']

# %%
data = b'\xbc\x00\x00'  # 주어진 바이트열 예시
decoded_data = data.decode('latin-1')  # "latin-1" 코덱 사용하여 디코드

# %%
import numpy as np ## numpy를 np로 import 한다
import pandas as pd ## pandas를 pd로 import 한다
import matplotlib.pyplot as plt ##matplotlib.pyplot을 plt로 import 한다
import seaborn as sns ##seaborn을 sns로 import 한다

# %%
import pandas as pd ## pandas의 read_csv를 통해서 단순 excel 파일 불러오기
data = pd.read_csv('ships (2).csv')
data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_28556\212424736.py:2: DtypeWarning: Columns (6,8,28,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('ships (2).csv')
#       선박국적코드 선박국적코드명    총 톤 수   IMO 번호   국제 총톤수     순 톤수 내외항구분코드 내외항구분명  \
# 0         PA     파나마  75519.0  9262728  75519.0  29555.0       1     외항
# 1         SL  시에라 리온   1334.0  8514124   1334.0    717.0       1     외항
# 2         CY   사이프러스  33042.0  9594420  33042.0  19132.0       1     외항
# 3         KR    대한민국     78.0      NaN     78.0     78.0       2     내항
# 4         KR    대한민국      8.0      NaN      NaN      8.0       2     내항
# ...      ...     ...      ...      ...      ...      ...     ...    ...
# 22790     PA     파나마  36518.0  9726516  36518.0  21292.0     1.0     외항
# 22791     NO    노르웨이  21897.0  9127667  21897.0  12597.0     1.0     외항
# 22792     HK      홍콩  32540.0  9755464  32540.0  19282.0     1.0     외항
# ...

# %%
Data = data.drop(columns=['선박 번호','톤수증서구분','톤수증서구분명','전호출부호',
                          '말소사유명(한글명)','말소사유명(영문명)','IMO 번호','변경유무','선박명(영문명)',
                          '청코드','청코드명',
                          '선박운영자 코드','선박건조(재계측)일자','유조선이중선체여부',
                          '호출부호','선주국적코드명','선박국적코드',
                          '내외항구분코드','내외항구분명','선적항 항구 코드','선적항 국가 코드',
                          '선박운영자 국적코드','선적항 항구 코드명','선박국적코드명','선박운영자 국적코드명','선적항 국가 코드명','선박명(한글)','운항형태코드명','국제 총톤수']) ##  data내에서 불필요한 정보 들을 전부 
                                                                                   ##삭제하고 필요한정보인 선박의 주요치수 등만 남긴다
Data
# Out:
#          총 톤 수     순 톤수  선박 총길이  선박 너비  선박 흘수  선박 깊이   선박 길이 선박 종류    선박 종류명  \
# 0      75519.0  29555.0   299.9   40.0   12.7  23.90  287.70    41    풀컨테이너선
# 1       1334.0    717.0    71.0   11.5    5.5   6.70   70.60    39     일반화물선
# 2      33042.0  19132.0   185.0   32.2   12.8  18.00  185.00    21  산물선(벌크선)
# 3         78.0     78.0    29.0    6.0    2.2   2.60   29.00    52  석유제품 운반선
# 4          8.0      8.0    13.0    3.1    1.0   1.17   12.48    99       기타선
# ...        ...      ...     ...    ...    ...    ...     ...   ...       ...
# 22790  36518.0  21292.0   199.9   32.3   13.3  18.50  194.80    21  산물선(벌크선)
# 22791  21897.0  12597.0   178.5   29.0   10.0  15.00  178.50    53   케미칼 운반선
# 22792  32540.0  19282.0   190.0   32.3   12.6  18.00  186.40    21  산물선(벌크선)
# 22793  92198.0  53625.0   331.9   42.8   15.0  21.00  331.90    41    풀컨테이너선
# 22794  20767.0  12116.0   179.9   28.4    6.5  14.10  172.40    39     일반화물선
#
#          재화중량
# 0        0.00
# ...

# %%
Data2 = Data[(Data["선박 종류명"]=='석유제품 운반선')|(Data["선박 종류명"]=='원유운반선')|(Data["선박 종류명"]=='기타 유조선')]

# %%
Data2
# Out:
#           총 톤 수      순 톤수  선박 총길이  선박 너비  선박 흘수  선박 깊이   선박 길이 선박 종류  \
# 3          78.0      78.0    29.0    6.0    2.2   2.60   29.00    52
# 20         33.0      33.0    22.5    5.0    2.3   2.30   22.50    59
# 22      83545.0   49022.0   274.5   48.0   15.0  23.70  264.00    51
# 29         20.0      20.0    19.3    3.9    2.1   2.10   19.30    52
# 35      85030.0   52098.0   274.7   47.9   17.3  24.00  265.90    52
# ...         ...       ...     ...    ...    ...    ...     ...   ...
# 22763   29917.0   13732.0   177.0   32.2   10.0  19.10  176.20    52
# 22778   29875.0   13834.0   175.0   32.0    8.0  19.10  175.00    59
# 22785  157092.0  101213.0   336.0   60.0   21.5  29.50  336.00    51
# 22786      46.0      46.0    24.0    5.4    2.5   2.50   24.00    59
# 22787     149.0     149.0    35.3    7.2    3.6   3.65   35.25    52
#
#          선박 종류명       재화중량
# 3      석유제품 운반선     156.46
# 20       기타 유조선      33.00
# 22        원유운반선  156827.00
# ...

# %%
import numpy as np

def get_outlier(df=None, column=None, weight=1.5):
  # target 값과 상관관계가 높은 열을 우선적으로 진행
  quantile_25 = np.percentile(df[column].values, 25)
  quantile_75 = np.percentile(df[column].values, 75)

  IQR = quantile_75 - quantile_25
  IQR_weight = IQR*weight
  
  lowest = quantile_25 - IQR_weight
  highest = quantile_75 + IQR_weight
  
  outlier_idx = df[column][ (df[column] < lowest) | (df[column] > highest) ].index
  return outlier_idx

# %%
outlier_idx = get_outlier(df=Datafinal, column='선박 길이', weight=1.5)
Datafinal.drop(outlier_idx, axis=0, inplace=True)
outlier_idx = get_outlier(df=Datafinal, column='선박 너비', weight=1.5)
Datafinal.drop(outlier_idx, axis=0, inplace=True)
outlier_idx = get_outlier(df=Datafinal, column='선박 깊이', weight=1.5)
Datafinal.drop(outlier_idx, axis=0, inplace=True)
outlier_idx = get_outlier(df=Datafinal, column='선박 총길이', weight=1.5)
Datafinal.drop(outlier_idx, axis=0, inplace=True)

Datafinal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 outlier_idx = get_outlier(df=Datafinal, column='선박 길이', weight=1.5)
#       2 Datafinal.drop(outlier_idx, axis=0, inplace=True)
#       3 outlier_idx = get_outlier(df=Datafinal, column='선박 너비', weight=1.5)
#
# NameError: name 'Datafinal' is not defined

# %%
Datafinal = Data2[Data2.재화중량 != 0]

# %%
Datafinal
# Out:
#           총 톤 수      순 톤수  선박 총길이  선박 너비  선박 흘수  선박 깊이   선박 길이 선박 종류  \
# 3          78.0      78.0    29.0    6.0    2.2   2.60   29.00    52
# 20         33.0      33.0    22.5    5.0    2.3   2.30   22.50    59
# 22      83545.0   49022.0   274.5   48.0   15.0  23.70  264.00    51
# 29         20.0      20.0    19.3    3.9    2.1   2.10   19.30    52
# 35      85030.0   52098.0   274.7   47.9   17.3  24.00  265.90    52
# ...         ...       ...     ...    ...    ...    ...     ...   ...
# 22763   29917.0   13732.0   177.0   32.2   10.0  19.10  176.20    52
# 22778   29875.0   13834.0   175.0   32.0    8.0  19.10  175.00    59
# 22785  157092.0  101213.0   336.0   60.0   21.5  29.50  336.00    51
# 22786      46.0      46.0    24.0    5.4    2.5   2.50   24.00    59
# 22787     149.0     149.0    35.3    7.2    3.6   3.65   35.25    52
#
#          선박 종류명       재화중량
# 3      석유제품 운반선     156.46
# 20       기타 유조선      33.00
# 22        원유운반선  156827.00
# ...

# %%
Datafinal2 = Datafinal.sort_values('선박 너비',ascending = False)

# %%
Datafinal2
# Out:
#           총 톤 수      순 톤수  선박 총길이    선박 너비  선박 흘수  선박 깊이  선박 길이 선박 종류  \
# 6274    12138.0    6255.0   145.0  2402.00    9.7  13.20  139.0    52
# 3261   162629.0  101960.0   333.0   324.53   21.8  30.00   60.0    51
# 11200    7430.0    3859.0   124.0   116.00    5.0  20.00   11.2    52
# 16060  234006.0  162477.0   366.4    68.00   20.0  30.30  366.4    51
# 17659  154098.0   97482.0   321.6    62.00   10.0  27.50  321.6    51
# ...         ...       ...     ...      ...    ...    ...    ...   ...
# 8772       10.0      10.0    13.8     3.10    1.5   1.50   13.8    52
# 5087       10.0      10.0    13.6     3.00    1.0   1.40   13.6    52
# 4394       15.0      15.0    15.2     2.90    1.0   1.60   15.2    51
# 13993      43.0       0.0    23.8     2.30    2.3   2.30   23.7    51
# 10239      39.0       0.0    19.1     0.40    1.0   1.94    1.9    52
#
#          선박 종류명      재화중량
# 6274   석유제품 운반선   19997.0
# 3261      원유운반선  307434.3
# 11200  석유제품 운반선   12384.0
# ...

# %%
type(Data2)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.DataFrame(Data2)

# %%
data
# Out:
#           총 톤 수      순 톤수  선박 총길이  선박 너비  선박 흘수  선박 깊이   선박 길이 선박 종류  \
# 3          78.0      78.0    29.0    6.0    2.2   2.60   29.00    52
# 20         33.0      33.0    22.5    5.0    2.3   2.30   22.50    59
# 22      83545.0   49022.0   274.5   48.0   15.0  23.70  264.00    51
# 29         20.0      20.0    19.3    3.9    2.1   2.10   19.30    52
# 35      85030.0   52098.0   274.7   47.9   17.3  24.00  265.90    52
# ...         ...       ...     ...    ...    ...    ...     ...   ...
# 22763   29917.0   13732.0   177.0   32.2   10.0  19.10  176.20    52
# 22778   29875.0   13834.0   175.0   32.0    8.0  19.10  175.00    59
# 22785  157092.0  101213.0   336.0   60.0   21.5  29.50  336.00    51
# 22786      46.0      46.0    24.0    5.4    2.5   2.50   24.00    59
# 22787     149.0     149.0    35.3    7.2    3.6   3.65   35.25    52
#
#          선박 종류명       재화중량
# 3      석유제품 운반선     156.46
# 20       기타 유조선      33.00
# 22        원유운반선  156827.00
# ...

# %%
Data3 = data.drop(6274)

# %%
Data3
# Out:
#           총 톤 수      순 톤수  선박 총길이  선박 너비  선박 흘수  선박 깊이   선박 길이 선박 종류  \
# 3          78.0      78.0    29.0    6.0    2.2   2.60   29.00    52
# 20         33.0      33.0    22.5    5.0    2.3   2.30   22.50    59
# 22      83545.0   49022.0   274.5   48.0   15.0  23.70  264.00    51
# 29         20.0      20.0    19.3    3.9    2.1   2.10   19.30    52
# 35      85030.0   52098.0   274.7   47.9   17.3  24.00  265.90    52
# ...         ...       ...     ...    ...    ...    ...     ...   ...
# 22763   29917.0   13732.0   177.0   32.2   10.0  19.10  176.20    52
# 22778   29875.0   13834.0   175.0   32.0    8.0  19.10  175.00    59
# 22785  157092.0  101213.0   336.0   60.0   21.5  29.50  336.00    51
# 22786      46.0      46.0    24.0    5.4    2.5   2.50   24.00    59
# 22787     149.0     149.0    35.3    7.2    3.6   3.65   35.25    52
#
#          선박 종류명       재화중량
# 3      석유제품 운반선     156.46
# 20       기타 유조선      33.00
# 22        원유운반선  156827.00
# ...

# %%
Data4 = Data3.sort_values('선박 너비',ascending = False)
Data4
# Out:
#           총 톤 수      순 톤수  선박 총길이   선박 너비  선박 흘수  선박 깊이  선박 길이 선박 종류  \
# 3261   162629.0  101960.0   333.0  324.53   21.8  30.00   60.0    51
# 11200    7430.0    3859.0   124.0  116.00    5.0  20.00   11.2    52
# 16060  234006.0  162477.0   366.4   68.00   20.0  30.30  366.4    51
# 17659  154098.0   97482.0   321.6   62.00   10.0  27.50  321.6    51
# 16985  164241.0  108543.0   333.0   60.30   12.7  30.50  322.0    51
# ...         ...       ...     ...     ...    ...    ...    ...   ...
# 5087       10.0      10.0    13.6    3.00    1.0   1.40   13.6    52
# 4394       15.0      15.0    15.2    2.90    1.0   1.60   15.2    51
# 13993      43.0       0.0    23.8    2.30    2.3   2.30   23.7    51
# 13290   45001.0   45001.0     1.0    1.00    1.0  99.90    1.0    52
# 10239      39.0       0.0    19.1    0.40    1.0   1.94    1.9    52
#
#          선박 종류명      재화중량
# 3261      원유운반선  307434.3
# 11200  석유제품 운반선   12384.0
# 16060     원유운반선       NaN
# 17659     원유운반선       NaN
# ...

# %%
Data5 = Data4.dropna()

# %%
Data4 = Datafinal

# %%
Datafinal.corr()
# Out:
#            총 톤 수      순 톤수    선박 총길이     선박 너비     선박 흘수     선박 깊이     선박 길이  \
# 총 톤 수   1.000000  0.993442  0.900647  0.327851  0.717339  0.839208  0.900117
# 순 톤수    0.993442  1.000000  0.865472  0.316560  0.692054  0.795968  0.864819
# 선박 총길이  0.900647  0.865472  1.000000  0.352354  0.771507  0.952909  0.996078
# 선박 너비   0.327851  0.316560  0.352354  1.000000  0.277822  0.337004  0.345889
# 선박 흘수   0.717339  0.692054  0.771507  0.277822  1.000000  0.752844  0.771925
# 선박 깊이   0.839208  0.795968  0.952909  0.337004  0.752844  1.000000  0.951779
# 선박 길이   0.900117  0.864819  0.996078  0.345889  0.771925  0.951779  1.000000
# 재화중량    0.996484  0.995276  0.887184  0.304572  0.699135  0.820203  0.886233
#
#             재화중량
# 총 톤 수   0.996484
# 순 톤수    0.995276
# 선박 총길이  0.887184
# 선박 너비   0.304572
# 선박 흘수   0.699135
# 선박 깊이   0.820203
# 선박 길이   0.886233
# 재화중량    1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

# seaborn 의 set 기능을 통해 폰트, 마이너스 폰트 설정, 스타일 설정을 합니다.

plt.figure(figsize=(10,10))
sns.heatmap(data = Data5.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(Data5, size=2, hue='선박 종류명', vars=['총 톤 수','선박 총길이'])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(Data4, size=2, hue='선박 종류명', vars=['총 톤 수','선박 너비'])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(Data5, size=2, hue='선박 종류명', vars=['총 톤 수','선박 너비'])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x="선박 총길이", y="총 톤 수", palette="red", height=5, data=Data4)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.figure(figsize=(15,5))
plt.plot(Data5['선박 길이'],Data5['선박 흘수'],'ro',markersize=5)
plt.title('선박 길이 - 선박 흘수 Graph',fontsize = 20)
plt.xlabel('선박 길이(m)',fontsize = 15)
plt.ylabel('선박 흘수(m)',fontsize = 15)

X = Data5['선박 길이']
y = Data5['선박 흘수']

line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)),'b--')

x_value = 250   # 예측하려는 x 값

predicted_y = line_fitter.predict([[x_value]])
print(predicted_y)
# Out:
# [14.10778927]

# %%
plt.figure(figsize=(15,5))
plt.plot(Data5['선박 길이'],Data5['선박 너비'],'ro',markersize=5)
plt.title('선박 길이 - 선박 너비 Graph',fontsize = 20)
plt.xlabel('선박 길이(m)',fontsize = 15)
plt.ylabel('선박 너비(m)',fontsize = 15)

X = Data5['선박 길이']
y = Data5['선박 너비']

line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)),'b--')

x_value = 250   # 예측하려는 x 값

predicted_y = line_fitter.predict([[x_value]])
print(predicted_y)
# Out:
# [44.73233944]

# %%
plt.figure(figsize=(15,5))
plt.plot(Data5['선박 길이'],Data5['선박 깊이'],'ro',markersize=5)
plt.title('선박 길이 - 선박 깊이 Graph',fontsize = 20)
plt.xlabel('선박 길이(m)',fontsize = 15)
plt.ylabel('선박 깊이(m)',fontsize = 15)

X = Data5['선박 길이']
y = Data5['선박 깊이']

line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)),'b--')

x_value = 250   # 예측하려는 x 값

predicted_y = line_fitter.predict([[x_value]])
print(predicted_y)
# Out:
# [22.95581838]

# %%
plt.figure(figsize=(15,5))
plt.plot(Data5['총 톤 수'],Data5['선박 깊이'],'ro',markersize=5)
plt.title('DWT - 선박 깊이 Graph',fontsize = 20)
plt.xlabel('DWT(ton)',fontsize = 15)
plt.ylabel('선박 깊이(m)',fontsize = 15)

X = Data5['총 톤 수']
y = Data5['선박 깊이']

line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)),'b--')

x_value = 113000   # 예측하려는 x 값

predicted_y = line_fitter.predict([[x_value]])
print(predicted_y)
# Out:
# [25.65237528]

# %%
plt.figure(figsize=(15,5))
plt.plot(Data5['총 톤 수'],Data5['선박 흘수'],'ro',markersize=5)
plt.title('DWT - 선박 흘수 Graph',fontsize = 20)
plt.xlabel('DWT(ton)',fontsize = 15)
plt.ylabel('선박 흘수(m)',fontsize = 15)

X = Data5['총 톤 수']
y = Data5['선박 흘수']

line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)),'b--')

x_value = 113000   # 예측하려는 x 값

predicted_y = line_fitter.predict([[x_value]])
print(predicted_y)
# Out:
# [15.93194132]

# %%
plt.figure(figsize=(15,5))
plt.plot(Data5['총 톤 수'],Data5['선박 너비'],'ro',markersize=5)
plt.title('DWT - 너비 Graph',fontsize = 20)
plt.xlabel('DWT(ton)',fontsize = 15)
plt.ylabel('선박 너비(m)',fontsize = 15)

X = Data5['총 톤 수']
y = Data5['선박 너비']

line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)),'b--')

x_value = 113000   # 예측하려는 x 값

predicted_y = line_fitter.predict([[x_value]])
print(predicted_y)
# Out:
# [51.70446881]

# %%
plt.figure(figsize=(15,5))
plt.plot(Data5['선박 너비'],Data5['선박 흘수'],'ro',markersize=5)
plt.title('선박 너비 - 선박 흘수 Graph',fontsize = 20)
plt.xlabel('선박 길이(m)',fontsize = 15)
plt.ylabel('선박 흘수(m)',fontsize = 15)

X = Data5['선박 너비']
y = Data5['선박 흘수']

line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1), y)
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)),'b--')

x_value = 43.8   # 예측하려는 x 값

predicted_y = line_fitter.predict([[x_value]])
print(predicted_y)
# Out:
# [13.53803265]
